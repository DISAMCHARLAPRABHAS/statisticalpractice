# %% [markdown]
# <a href="https://colab.research.google.com/github/DISAMCHARLAPRABHAS/statisticalpractice/blob/main/diabetic_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path='C:/Users/Admin/diabetic_data1.csv'
df=pd.read_csv(file_path)
print(df.head())
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
import pandas as pd
file_path='C:/Users/Admin/diabetic_data1.csv'
df=pd.read_csv(file_path)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path='C:/Users/Admin/diabetic_data1.csv'
df=pd.read_csv(file_path)
gender=df['gender'].value_counts()
gender.plot(kind='pie' , autopct='%1.1f%%', figsize=(8,8), colors=['green','blue'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path='C:/Users/Admin/diabetic_data1.csv'
df=pd.read_csv(file_path)
# Check for null values in the dataset
print("Null values in dataset:")
print(df.isnull().sum())

# Drop rows with null values
cleaned_data = df.dropna()

# Display the cleaned dataset
print("\nCleaned Dataset:")
print(cleaned_data)

# Save the cleaned dataset if needed
cleaned_data.to_csv('cleaned_diabetic_data.csv', index=False)
# Out:
# Null values in dataset:
# encounter_id                    0
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# weight                          0
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                      0
# medical_specialty               0
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                          0
# diag_2                          0
# diag_3                          0
# number_diagnoses                0
# max_glu_serum               96420
# A1Cresult                   84748
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...
